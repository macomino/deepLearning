# %% [markdown]
# # Introduction to Neural Networks and Deep Learning

# %% [markdown]
# ## What's the difference between Artificial Intelligence, Machine Learning and Deep Learning?
#
# **Artificial Intelligence** (AI) is a very old field of research. It started in the 1950s; at that time, the pioneers in AI were convinced that they could make machines think. The initial approach was attempting to model intellectual tasks, and program those tasks in computers. That is, in the beginning, AI was about people *hard-coding* problems that the machine tried to solve. A good example of an early AI program is computer chess. Early AI computer chess programs had **lots of rules pre-conceived by the program designers**. So although the term refers to "intelligence", these programs were not "intelligent", but just a sophisticated set of rules.
#
# * The term *neural network* was also born at that time. The initial idea was trying to mimic how a *neuron* works (or in fact, how it was thought a neuron worked when the term was coined) in the brain. As in the case of *Artificial Intelligence*, please do not be fooled by the terms. A *neural network* is just a way to compute approximation to functions. A powerful and useful way, true. But it is not any kind of "artificial brain", or anything like that.
#
# This approach is now obsolete. We now know that some tasks are so complex, that we will never be able to pre-design a system to have a good performance on those tasks. Take the example of the game of Go. Any program designed by humans to play Go was dull and could not compete against professional players. The game is so hard that is just impossible for us as humans to conceived a good Go computer player.
# * https://en.wikipedia.org/wiki/Go_(game)
#
# The modern approach to solve this kind of problems involves the use of data. This is what the *learning* part of *Deep Learning* (and *Machine Learning*) refers to. **Learning from data**. So, with this brief introduction, we can say that *Artificial Intelligence* is a broad concept that includes *Machine Learning*, that includes *Deep Learning*. *Artificial Intelligence* does not necessarily means learning from data, but Machine Learning does. And *Deep Learning* is just doing *Machine Learning* with neural networks.
#
# ![](imgs/01_ai_ml_dl.png)
#
# We will see during this course what *learning* means, and what is a *neural network*.
#
# In the case of the game of Go, all attempts to design a good Go computer player failed, until Google DeepMind created AlphaGo, a system that *learned* to play Go based on data from previous games. AlphaGo is an example that learning from data can provide computer systems that are superior to any system pre-conceived by humans.
# * Find out more about AlphaGo by watching this utterly interesting movie: https://www.alphagomovie.com/
#
# In this course, we will give our first steps on *Deep Learning* and *Neural Networks*, to start creating systems that perform complex tasks by learning from data. Instead of attempting to derive the rules by ourselves, those rules will be inferred by a neural network based on the data we provide:
#
# ![](imgs/02_rules_data.png)

# %% [markdown]
# # Deep Learning and Machine Learning: why is everyone now talking about Deep Learning?
#
# To create our system, we need data:
# * Input data points; e.g. images to recognize shapes inside the images.
# * Examples of expected output. The system will use these examples to learn from them. For the images above, we will need *labels* telling us what is in the image.
#
# The neural network will *learn* from this data. But in fact, what the network is doing is learning a *representation* of the data that makes the task much easier to solve.
#
# Let's see an example. We have the following input data (x,y coordinates for the points), and the labels of each item (the color of the point). We would like to obtain a model to separete the two classes of points:
#
# ![](imgs/03_points.png)
#
# How would you separate the points? In the current reference system, it can be a complex task. But if you change the reference system (*if you learn a new representation of the data*), the task becomes trivial:
#
# ![](imgs/04_representation.png)
#
# In Deep Learning, we learn **layers** of increasingly better representations. The **deep** in Deep Learning refers to the number of layers that we learn. Before Deep Learning, the models that we are going to see today were much shallower. The most typical form of the layer representations is **neural networks**. As we will see, **neural networks** are just chain of matrix operations -- arrays of 2 dimensions--, or more precisely, tensor operations, we will operate in dimensions higher than 2.
#
#
# * More about learning representations: https://www.bbvadata.com/not-deep-learning-learning-represent/

# %% [markdown]
# ## Neural Networks
#
# A neural network is just a stacked set of layers. Each layer is represented by a tensor, and it performs an affine transformation on each one of the layers.
# * A matrix is a 2D tensor
# * Affine transformation $\vec{y} = W\cdot\vec{x} + \vec{b}$, where $W$ is the weights tensor, $\vec{x}$ is the input data, $\vec{y}$ is the output data and $\vec{b}$ is called the bias
# * $W$ and $\vec{b}$ are model parameters that need to be found by training
#
# ![](imgs/05_nn.png)
#
# Note that this is a **linear operation**, therefore the result will be linear too. But the functions we want to learn are normally non-linear. How do we overcome this limiation? By using an **activation function**, that transforms the result from the linear operation. So, we actually do the following operation:
#
# $\vec{y} = f\left(W\cdot\vec{x} + \vec{b}\right)$
#
# There are several common activation functions, depending on the characteristics of the data and the kind of problem we want to solve. Here we will use the probably most often used activation function: **rectified linear unit**, or **relu** for friends:
#
# ![Relu plot](https://upload.wikimedia.org/wikipedia/commons/6/6c/Rectifier_and_softplus_functions.svg)
#
# (image extracted from https://en.wikipedia.org/wiki/Rectifier_(neural_networks))
#
# Relu will add the non-linearity that we need to learn arbitrary functions.
#
# We can achieve the same with many other activation functions. See the documentation of Keras for details on the available activation functions:
#  - https://keras.io/activations/
#
#
# Each layer learns a new representation of the input data, and after several layers, the representation will make it straightforward to solve the task (e.g. assiging a digit to an image of a digit).
#
# Until very recently, any attempt to train a deep neural network would not provide good results. Recent progresses (e.g. advances in hardware, new activation functions) make it possible to train very deep network, and therefore, solve problems that were unfeasible not long ago.
#
# ### Training process
#
# The parameters of the network are initially randomly assigned. Then after each pass of the network, that is, after each *epoch*, the predictions of the network is compared against the true values, applying a *loss function*. This score is used to update the parameters of the network, with a process called **backpropagation**.
# * Backpropagation is a complex process that involves calculating the gradient of the parameters of the network. For more details see: https://en.wikipedia.org/wiki/Backpropagation
# * See also this excellent and visual explanation of how backpropagation works: https://google-developers.appspot.com/machine-learning/crash-course/backprop-scroll/
#
# The training process is just an optimization process, that is normally done using a gradient descent-based algorithm. The values of gradients are computed using the backpropagation algorithm. Each epoch will make the loss score to be lower, and the predictions to be better.
#
# ![](imgs/06_optim.png)
#
# In practice, we have to fine tune the number of epochs (and other parameters), until we obtain a result that is good enough for our purpose. In fact, if the number of epochs is too high, our model may **overfit** the training data. In that case, it will perform worsely when the model is exposed to data that it  has not seen previously.
# * Fine tuning the number of epochs, and other parameters (e.g. the number and shape of the layers) is known as **hyperparameters optimization**, or **hyperparameters tuning**
# * The parameters of the model are the $W$ and $b$ values of each layer, and those are determined by training.
#
# ## Hyperparameters tuning
#
# In summary, when we are trying to obtain a deep learning model, the process that we will follow is:
# * Decide on the architecture of the network (number of layers, type of each layer, size of each layer)
# * Decide on the activation functions on each layer
# * Decide on the parameters related to the optimization process (e.g. learning rate)
# * Decide on the loss function that we will use
# * Decide on the metrics that we will use to evaluate the performance of the model
# * Decide on the training parameters (number of epochs, batch size)
# * Decide on how to split the data between training, validation and test sets.
#
# We obtain feedback for those decisions with the results of the training applied to the validation set. We train once, change some of the hyperparameters, train again, decide if that's better, and we keep going until we have found a model that is satisfactory enough for our purposes.
#
# After that, we finally evaluate the model on the test set.

# %% [markdown]
# ## Our first neural network
#
# Let's start with an easy example. We are going to produce some synthetic data, and will try to predict the function that generates the data. We will add some noise, to make the problem more difficult.
#
# The function we are going to try to predict is
#
# $\displaystyle y = 3*x + 2$

# %%
# %pylab inline
plt.style.use('seaborn-talk')
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def plot_metric(history, metric):
    history_dict = history.history
    values = history_dict[metric]
    if 'val_' + metric in history_dict.keys():  
        val_values = history_dict['val_' + metric]

    epochs = range(1, len(values) + 1)

    if 'val_' + metric in history_dict.keys():  
        plt.plot(epochs, val_values, label='Validation')
    plt.semilogy(epochs, values, label='Training')

    if 'val_' + metric in history_dict.keys():  
        plt.title('Training and validation %s' % metric)
    else:
        plt.title('Training %s' % metric)
    plt.xlabel('Epochs')
    plt.ylabel(metric.capitalize())
    plt.legend()

    plt.show()

# %% [markdown]
# ### Preparar los datos

# %%
x_train = np.linspace(0, 100, 1000)
y_train = 3*x_train + 2

# %%
plot(x_train, y_train)

# %% [markdown]
# ### Now another more complex function
#
# Let's try to fit a parabollic function
#
# $\displaystyle y = -2x^2 + x + 1$

# %%
from keras import layers

# %%
from keras import models

# %%
m = models.Sequential()

# %%
models.Model??

# %%
m = models.Sequential()
m.add(layers.Dense(input_shape=(1,), activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense( activation='relu', units=64))
m.add(layers.Dense(activation=None, units=1))

# %%
m.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_18 (Dense)             (None, 64)                128
# _________________________________________________________________
# dense_19 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_20 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_21 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_22 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_23 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_24 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_25 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_26 (Dense)             (None, 64)                4160
# _________________________________________________________________
# dense_27 (Dense)             (None, 1)                 65
# =================================================================
# Total params: 33,473
# Trainable params: 33,473
# Non-trainable params: 0
# _________________________________________________________________

# %%
from keras import losses, optimizers, metrics

# %%
m.compile(loss=losses.mse, optimizer=optimizers.rmsprop(), metrics=[metrics.mean_absolute_error])

# %%
h = m.fit(x=x_train, y=y_train, batch_size=100, epochs=40, validation_split=0.2)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/40
# 800/800 [==============================] - 1s 651us/step - loss: 15508.3809 - mean_absolute_error: 106.7806 - val_loss: 9747.0767 - val_mean_absolute_error: 98.5287
# Epoch 2/40
# 800/800 [==============================] - 0s 68us/step - loss: 376.9915 - mean_absolute_error: 8.4596 - val_loss: 2.2373 - val_mean_absolute_error: 1.4904
# Epoch 3/40
# 800/800 [==============================] - 0s 68us/step - loss: 16.8795 - mean_absolute_error: 2.5149 - val_loss: 1161.5396 - val_mean_absolute_error: 34.0100
# Epoch 4/40
# 800/800 [==============================] - 0s 67us/step - loss: 269.1431 - mean_absolute_error: 13.9806 - val_loss: 605.0448 - val_mean_absolute_error: 24.5456
# Epoch 5/40
# 800/800 [==============================] - 0s 68us/step - loss: 109.3843 - mean_absolute_error: 8.9178 - val_loss: 829.4665 - val_mean_absolute_error: 28.7399
# Epoch 6/40
# 800/800 [==============================] - 0s 67us/step - loss: 167.7872 - mean_absolute_error: 11.0135 - val_loss: 368.5889 - val_mean_absolute_error: 19.1577
# Epoch 7/40
# 800/800 [==============================] - 0s 69us/step - loss: 165.5786 - mean_absolute_error: 11.0690 - val_loss: 451.3014 - val_mean_absolute_error: 21.1988
# Epoch 8/40
# 800/800 [==============================] - 0s 67us/step - loss: 122.7612 - mean_absolute_error: 9.2091 - val_loss: 222.2619 - val_mean_absolute_error: 14.8764
# Epoch 9/40
# 800/800 [==============================] - 0s 69us/step - loss: 182.1937 - mean_absolute_error: 11.3686 - val_loss: 426.0637 - val_mean_absolute_error: 20.5977
# Epoch 10/40
# 800/800 [==============================] - 0s 66us/step - loss: 120.4879 - mean_absolute_error: 9.4298 - val_loss: 639.0719 - val_mean_absolute_error: 25.2269
# Epoch 11/40
# 800/800 [==============================] - 0s 69us/step - loss: 184.7797 - mean_absolute_error: 11.2709 - val_loss: 53.2679 - val_mean_absolute_error: 7.2821
# Epoch 12/40
# 800/800 [==============================] - 0s 67us/step - loss: 99.4877 - mean_absolute_error: 7.7580 - val_loss: 760.1056 - val_mean_absolute_error: 27.5125
# Epoch 13/40
# 800/800 [==============================] - 0s 67us/step - loss: 155.3134 - mean_absolute_error: 10.0262 - val_loss: 147.3097 - val_mean_absolute_error: 12.1111
# Epoch 14/40
# 800/800 [==============================] - 0s 65us/step - loss: 172.3373 - mean_absolute_error: 10.8579 - val_loss: 186.3730 - val_mean_absolute_error: 13.6228
# Epoch 15/40
# 800/800 [==============================] - 0s 66us/step - loss: 110.7346 - mean_absolute_error: 8.8564 - val_loss: 416.3317 - val_mean_absolute_error: 20.3616
# Epoch 16/40
# 800/800 [==============================] - 0s 69us/step - loss: 145.3630 - mean_absolute_error: 9.9925 - val_loss: 159.3976 - val_mean_absolute_error: 12.5986
# Epoch 17/40
# 800/800 [==============================] - 0s 68us/step - loss: 171.7488 - mean_absolute_error: 10.6272 - val_loss: 550.6863 - val_mean_absolute_error: 23.4181
# Epoch 18/40
# 800/800 [==============================] - 0s 74us/step - loss: 103.9947 - mean_absolute_error: 8.6767 - val_loss: 286.1981 - val_mean_absolute_error: 16.8821
# Epoch 19/40
# 800/800 [==============================] - 0s 76us/step - loss: 177.6870 - mean_absolute_error: 11.3485 - val_loss: 314.3094 - val_mean_absolute_error: 17.6919
# Epoch 20/40
# 800/800 [==============================] - 0s 69us/step - loss: 109.7544 - mean_absolute_error: 8.8435 - val_loss: 179.5999 - val_mean_absolute_error: 13.3735
# Epoch 21/40
# 800/800 [==============================] - 0s 73us/step - loss: 133.6654 - mean_absolute_error: 9.3804 - val_loss: 143.2284 - val_mean_absolute_error: 11.9428
# Epoch 22/40
# 800/800 [==============================] - 0s 69us/step - loss: 152.9521 - mean_absolute_error: 10.0941 - val_loss: 656.7779 - val_mean_absolute_error: 25.5750
# Epoch 23/40
# 800/800 [==============================] - 0s 71us/step - loss: 127.3548 - mean_absolute_error: 9.7667 - val_loss: 382.8012 - val_mean_absolute_error: 19.5249
# Epoch 24/40
# 800/800 [==============================] - 0s 68us/step - loss: 133.1703 - mean_absolute_error: 9.8710 - val_loss: 862.6792 - val_mean_absolute_error: 29.3112
# Epoch 25/40
# 800/800 [==============================] - 0s 70us/step - loss: 130.2749 - mean_absolute_error: 9.3995 - val_loss: 266.6000 - val_mean_absolute_error: 16.2942
# Epoch 26/40
# 800/800 [==============================] - 0s 71us/step - loss: 140.3898 - mean_absolute_error: 9.9907 - val_loss: 547.4451 - val_mean_absolute_error: 23.3496
# Epoch 27/40
# 800/800 [==============================] - 0s 69us/step - loss: 125.7687 - mean_absolute_error: 9.3200 - val_loss: 217.4415 - val_mean_absolute_error: 14.7155
# Epoch 28/40
# 800/800 [==============================] - 0s 71us/step - loss: 153.8971 - mean_absolute_error: 10.4021 - val_loss: 227.3497 - val_mean_absolute_error: 15.0472
# Epoch 29/40
# 800/800 [==============================] - 0s 69us/step - loss: 130.1584 - mean_absolute_error: 9.5475 - val_loss: 414.1737 - val_mean_absolute_error: 20.3097
# Epoch 30/40
# 800/800 [==============================] - 0s 70us/step - loss: 119.9051 - mean_absolute_error: 9.3818 - val_loss: 215.3959 - val_mean_absolute_error: 14.6464
# Epoch 31/40
# 800/800 [==============================] - 0s 68us/step - loss: 153.7998 - mean_absolute_error: 10.5230 - val_loss: 352.9150 - val_mean_absolute_error: 18.7478
# Epoch 32/40
# 800/800 [==============================] - 0s 69us/step - loss: 110.4618 - mean_absolute_error: 9.0688 - val_loss: 396.3432 - val_mean_absolute_error: 19.8679
# Epoch 33/40
# 800/800 [==============================] - 0s 69us/step - loss: 119.2190 - mean_absolute_error: 9.3425 - val_loss: 815.7717 - val_mean_absolute_error: 28.5038
# Epoch 34/40
# 800/800 [==============================] - 0s 70us/step - loss: 152.0668 - mean_absolute_error: 10.0571 - val_loss: 85.7786 - val_mean_absolute_error: 9.2429
# Epoch 35/40
# 800/800 [==============================] - 0s 71us/step - loss: 129.6438 - mean_absolute_error: 9.0526 - val_loss: 796.2564 - val_mean_absolute_error: 28.1608
# Epoch 36/40
# 800/800 [==============================] - 0s 82us/step - loss: 87.2660 - mean_absolute_error: 6.9713 - val_loss: 253.8273 - val_mean_absolute_error: 15.8998
# Epoch 37/40
# 800/800 [==============================] - 0s 74us/step - loss: 182.6903 - mean_absolute_error: 11.5620 - val_loss: 372.8557 - val_mean_absolute_error: 19.2705
# Epoch 38/40
# 800/800 [==============================] - 0s 70us/step - loss: 102.7975 - mean_absolute_error: 8.4535 - val_loss: 622.7705 - val_mean_absolute_error: 24.9050
# Epoch 39/40
# 800/800 [==============================] - 0s 73us/step - loss: 107.7245 - mean_absolute_error: 8.8270 - val_loss: 669.8366 - val_mean_absolute_error: 25.8290
# Epoch 40/40
# 800/800 [==============================] - 0s 68us/step - loss: 132.1376 - mean_absolute_error: 9.5674 - val_loss: 568.7405 - val_mean_absolute_error: 23.8002

# %%
plot_metric(h, 'loss')

# %%
err_t = np.mean(h.history['loss'][-40:])
err_v = np.mean(h.history['val_loss'][-40:])

# %%
err_t
# Out:
# 527.4033147728536

# %%
err_v
# Out:
# 659.3804976716638

# %%
def scale(x):
  x = (x - x.min())/float(x.max()-x.min())
  
def model(capas):
  m = models.Sequential()
  m.add(layers.Dense(input_shape=(1,), activation='relu', units=64))
  for i in range(0,capas):
    m.add(layers.Dense( activation='relu', units=10))
  m.add(layers.Dense(activation=None, units=1))
  m.compile(loss=losses.mse, optimizer=optimizers.rmsprop(), metrics=[metrics.mean_absolute_error])
  h = m.fit(x=x_train, y=y_train, batch_size=200, epochs=100, validation_split=0.2)
  return h

# %%
x_train = np.linspace(0, 100, 1000)
y_train = -2*x_train**2 + x_train + 1

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-95-0b167dc1fa82> in <module>()
# ----> 1 scale([2,3,4,5,4])
#
# <ipython-input-93-f642ef1a8dec> in scale(x)
#       1 def scale(x):
# ----> 2   x = (x - x.min())/float(x.max()-x.min())
#       3
#       4 def model(capas):
#       5   m = models.Sequential()
#
# AttributeError: 'list' object has no attribute 'min'

# %%
err_t_list = []
err_v_v = []
for v in range(0,10):
  m = model(v)
  err_t = np.mean(m.history['loss'][-40:])
  err_v = np.mean(m.history['val_loss'][-40:])
  err_t_list.append(err_t)
  err_v_v.append(err_v)
# Out:
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 8s 10ms/step - loss: 32161886.0000 - mean_absolute_error: 4217.1077 - val_loss: 265594272.0000 - val_mean_absolute_error: 16164.4424
# Epoch 2/100
# 800/800 [==============================] - 0s 36us/step - loss: 32120411.5000 - mean_absolute_error: 4213.7710 - val_loss: 265409312.0000 - val_mean_absolute_error: 16158.7666
# Epoch 3/100
# 800/800 [==============================] - 0s 36us/step - loss: 32090350.5000 - mean_absolute_error: 4211.3948 - val_loss: 265249744.0000 - val_mean_absolute_error: 16153.8672
# Epoch 4/100
# 800/800 [==============================] - 0s 35us/step - loss: 32063595.0000 - mean_absolute_error: 4209.2719 - val_loss: 265102208.0000 - val_mean_absolute_error: 16149.3389
# Epoch 5/100
# 800/800 [==============================] - 0s 36us/step - loss: 32038573.5000 - mean_absolute_error: 4207.2805 - val_loss: 264961248.0000 - val_mean_absolute_error: 16145.0088
# Epoch 6/100
# 800/800 [==============================] - 0s 37us/step - loss: 32014230.0000 - mean_absolute_error: 4205.3754 - val_loss: 264821568.0000 - val_mean_absolute_error: 16140.7158
# Epoch 7/100
# 800/800 [==============================] - 0s 35us/step - loss: 31990285.0000 - mean_absolute_error: 4203.4560 - val_loss: 264684688.0000 - val_mean_absolute_error: 16136.5117
# Epoch 8/100
# 800/800 [==============================] - 0s 35us/step - loss: 31966700.5000 - mean_absolute_error: 4201.5742 - val_loss: 264548800.0000 - val_mean_absolute_error: 16132.3350
# Epoch 9/100
# 800/800 [==============================] - 0s 35us/step - loss: 31943225.0000 - mean_absolute_error: 4199.7186 - val_loss: 264414160.0000 - val_mean_absolute_error: 16128.1934
# Epoch 10/100
# 800/800 [==============================] - 0s 38us/step - loss: 29038656.0000 - mean_absolute_error: 3963.3901 - val_loss: 247394816.0000 - val_mean_absolute_error: 15596.1035
# Epoch 94/100
# 800/800 [==============================] - 0s 39us/step - loss: 28988938.5000 - mean_absolute_error: 3959.2612 - val_loss: 247101760.0000 - val_mean_absolute_error: 15586.7842
# Epoch 95/100
# 800/800 [==============================] - 0s 38us/step - loss: 28939176.5000 - mean_absolute_error: 3955.0625 - val_loss: 246808384.0000 - val_mean_absolute_error: 15577.4492
# Epoch 96/100
# 800/800 [==============================] - 0s 39us/step - loss: 28889249.0000 - mean_absolute_error: 3950.8794 - val_loss: 246513600.0000 - val_mean_absolute_error: 15568.0615
# Epoch 97/100
# 800/800 [==============================] - 0s 40us/step - loss: 28839005.5000 - mean_absolute_error: 3946.6764 - val_loss: 246216112.0000 - val_mean_absolute_error: 15558.5820
# Epoch 98/100
# 800/800 [==============================] - 0s 37us/step - loss: 28788182.5000 - mean_absolute_error: 3942.4510 - val_loss: 245915552.0000 - val_mean_absolute_error: 15549.0000
# Epoch 99/100
# 800/800 [==============================] - 0s 43us/step - loss: 28736736.0000 - mean_absolute_error: 3938.2025 - val_loss: 245610208.0000 - val_mean_absolute_error: 15539.2598
# Epoch 100/100
# 800/800 [==============================] - 0s 41us/step - loss: 28684975.0000 - mean_absolute_error: 3933.8293 - val_loss: 245305648.0000 - val_mean_absolute_error: 15529.5371
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 8s 10ms/step - loss: 32349873.5000 - mean_absolute_error: 4231.8432 - val_loss: 266703520.0000 - val_mean_absolute_error: 16198.4385
# Epoch 2/100
# 800/800 [==============================] - 0s 41us/step - loss: 32313830.5000 - mean_absolute_error: 4229.0062 - val_loss: 266550944.0000 - val_mean_absolute_error: 16193.7646
# Epoch 3/100
# 800/800 [==============================] - 0s 36us/step - loss: 32291091.5000 - mean_absolute_error: 4227.2280 - val_loss: 266444752.0000 - val_mean_absolute_error: 16190.5127
# Epoch 4/100
# 800/800 [==============================] - 0s 37us/step - loss: 32278655.0000 - mean_absolute_error: 4226.2658 - val_loss: 266432960.0000 - val_mean_absolute_error: 16190.1523
# Epoch 5/100
# 800/800 [==============================] - 0s 37us/step - loss: 32277880.0000 - mean_absolute_error: 4226.2069 - val_loss: 266432816.0000 - val_mean_absolute_error: 16190.1475
# Epoch 6/100
# 800/800 [==============================] - 0s 37us/step - loss: 32277844.0000 - mean_absolute_error: 4226.2028 - val_loss: 266432656.0000 - val_mean_absolute_error: 16190.1436
# Epoch 7/100
# 800/800 [==============================] - 0s 45us/step - loss: 32277809.0000 - mean_absolute_error: 4226.1988 - val_loss: 266432560.0000 - val_mean_absolute_error: 16190.1396
# Epoch 8/100
# 800/800 [==============================] - 0s 43us/step - loss: 32277773.0000 - mean_absolute_error: 4226.1946 - val_loss: 266432432.0000 - val_mean_absolute_error: 16190.1367
# Epoch 9/100
# 800/800 [==============================] - 0s 41us/step - loss: 32277740.0000 - mean_absolute_error: 4226.1907 - val_loss: 266432288.0000 - val_mean_absolute_error: 16190.1328
# Epoch 10/100
# 800/800 [==============================] - 0s 35us/step - loss: 32277706.5000 - mean_absolute_error: 4226.1870 - val_loss: 266432160.0000 - val_mean_absolute_error: 16190.1279
# Epoch 11/100
# 800/800 [==============================] - 0s 37us/step - loss: 32277673.0000 - mean_absolute_error: 4226.1830 - val_loss: 266432048.0000 - val_mean_absolute_error: 16190.1240
# Epoch 12/100
# 800/800 [==============================] - 0s 38us/step - loss: 32277640.0000 - mean_absolute_error: 4226.1788 - val_loss: 266431904.0000 - val_mean_absolute_error: 16190.1201
# Epoch 13/100
# 800/800 [==============================] - 0s 38us/step - loss: 32277605.0000 - mean_absolute_error: 4226.1748 - val_loss: 266431760.0000 - val_mean_absolute_error: 16190.1152
# Epoch 14/100
# 800/800 [==============================] - 0s 36us/step - loss: 32277569.5000 - mean_absolute_error: 4226.1710 - val_loss: 266431648.0000 - val_mean_absolute_error: 16190.1123
# Epoch 15/100
# 800/800 [==============================] - 0s 41us/step - loss: 32277535.0000 - mean_absolute_error: 4226.1671 - val_loss: 266431536.0000 - val_mean_absolute_error: 16190.1074
# Epoch 16/100
# 800/800 [==============================] - 0s 39us/step - loss: 32277502.5000 - mean_absolute_error: 4226.1630 - val_loss: 266431392.0000 - val_mean_absolute_error: 16190.1055
# Epoch 17/100
# 800/800 [==============================] - 0s 43us/step - loss: 32277467.5000 - mean_absolute_error: 4226.1591 - val_loss: 266431264.0000 - val_mean_absolute_error: 16190.0996
# Epoch 18/100
# 800/800 [==============================] - 0s 39us/step - loss: 32277434.5000 - mean_absolute_error: 4226.1554 - val_loss: 266431072.0000 - val_mean_absolute_error: 16190.0938
# Epoch 19/100
# 800/800 [==============================] - 0s 34us/step - loss: 32277401.5000 - mean_absolute_error: 4226.1514 - val_loss: 266430992.0000 - val_mean_absolute_error: 16190.0898
# Epoch 20/100
# 800/800 [==============================] - 0s 39us/step - loss: 32277369.0000 - mean_absolute_error: 4226.1475 - val_loss: 266430848.0000 - val_mean_absolute_error: 16190.0859
# Epoch 21/100
# 800/800 [==============================] - 0s 44us/step - loss: 32277334.5000 - mean_absolute_error: 4226.1436 - val_loss: 266430736.0000 - val_mean_absolute_error: 16190.0840
# Epoch 22/100
# 800/800 [==============================] - 0s 44us/step - loss: 32277300.0000 - mean_absolute_error: 4226.1395 - val_loss: 266430592.0000 - val_mean_absolute_error: 16190.0791
# Epoch 23/100
# 800/800 [==============================] - 0s 46us/step - loss: 32277267.5000 - mean_absolute_error: 4226.1358 - val_loss: 266430464.0000 - val_mean_absolute_error: 16190.0752
# Epoch 24/100
# 800/800 [==============================] - 0s 46us/step - loss: 32277231.0000 - mean_absolute_error: 4226.1318 - val_loss: 266430336.0000 - val_mean_absolute_error: 16190.0713
# Epoch 25/100
# 800/800 [==============================] - 0s 38us/step - loss: 32277197.0000 - mean_absolute_error: 4226.1278 - val_loss: 266430176.0000 - val_mean_absolute_error: 16190.0664
# Epoch 26/100
# 800/800 [==============================] - 0s 40us/step - loss: 32277166.0000 - mean_absolute_error: 4226.1239 - val_loss: 266430096.0000 - val_mean_absolute_error: 16190.0625
# Epoch 27/100
# 800/800 [==============================] - 0s 36us/step - loss: 32277130.5000 - mean_absolute_error: 4226.1200 - val_loss: 266429952.0000 - val_mean_absolute_error: 16190.0586
# Epoch 28/100
# 800/800 [==============================] - 0s 40us/step - loss: 32277097.0000 - mean_absolute_error: 4226.1163 - val_loss: 266429808.0000 - val_mean_absolute_error: 16190.0547
# Epoch 29/100
# 800/800 [==============================] - 0s 46us/step - loss: 32277063.5000 - mean_absolute_error: 4226.1124 - val_loss: 266429712.0000 - val_mean_absolute_error: 16190.0508
# Epoch 30/100
# 800/800 [==============================] - 0s 46us/step - loss: 32277030.5000 - mean_absolute_error: 4226.1086 - val_loss: 266429568.0000 - val_mean_absolute_error: 16190.0479
# Epoch 31/100
# 800/800 [==============================] - 0s 40us/step - loss: 32276997.0000 - mean_absolute_error: 4226.1048 - val_loss: 266429440.0000 - val_mean_absolute_error: 16190.0439
# Epoch 32/100
# 800/800 [==============================] - 0s 35us/step - loss: 32276964.0000 - mean_absolute_error: 4226.1007 - val_loss: 266429312.0000 - val_mean_absolute_error: 16190.0400
# Epoch 33/100
# 800/800 [==============================] - 0s 45us/step - loss: 32276930.0000 - mean_absolute_error: 4226.0968 - val_loss: 266429168.0000 - val_mean_absolute_error: 16190.0352
# Epoch 34/100
# 800/800 [==============================] - 0s 35us/step - loss: 32276897.0000 - mean_absolute_error: 4226.0930 - val_loss: 266429072.0000 - val_mean_absolute_error: 16190.0312
# Epoch 35/100
# 800/800 [==============================] - 0s 39us/step - loss: 32276862.0000 - mean_absolute_error: 4226.0889 - val_loss: 266428912.0000 - val_mean_absolute_error: 16190.0273
# Epoch 36/100
# 800/800 [==============================] - 0s 44us/step - loss: 32276826.5000 - mean_absolute_error: 4226.0851 - val_loss: 266428800.0000 - val_mean_absolute_error: 16190.0234
# Epoch 37/100
# 800/800 [==============================] - 0s 47us/step - loss: 32276792.5000 - mean_absolute_error: 4226.0812 - val_loss: 266428688.0000 - val_mean_absolute_error: 16190.0186
# Epoch 38/100
# 800/800 [==============================] - 0s 39us/step - loss: 32276759.0000 - mean_absolute_error: 4226.0771 - val_loss: 266428544.0000 - val_mean_absolute_error: 16190.0166
# Epoch 39/100
# 800/800 [==============================] - 0s 38us/step - loss: 32276728.0000 - mean_absolute_error: 4226.0734 - val_loss: 266428416.0000 - val_mean_absolute_error: 16190.0127
# Epoch 40/100
# 800/800 [==============================] - 0s 36us/step - loss: 32276692.0000 - mean_absolute_error: 4226.0693 - val_loss: 266428256.0000 - val_mean_absolute_error: 16190.0078
# Epoch 41/100
# 800/800 [==============================] - 0s 39us/step - loss: 32276661.0000 - mean_absolute_error: 4226.0658 - val_loss: 266428112.0000 - val_mean_absolute_error: 16190.0029
# Epoch 42/100
# 800/800 [==============================] - 0s 44us/step - loss: 32276626.5000 - mean_absolute_error: 4226.0615 - val_loss: 266428032.0000 - val_mean_absolute_error: 16189.9990
# Epoch 43/100
# 800/800 [==============================] - 0s 33us/step - loss: 32274903.5000 - mean_absolute_error: 4225.8608 - val_loss: 266421408.0000 - val_mean_absolute_error: 16189.7959
# Epoch 94/100
# 800/800 [==============================] - 0s 41us/step - loss: 32274871.0000 - mean_absolute_error: 4225.8569 - val_loss: 266421296.0000 - val_mean_absolute_error: 16189.7930
# Epoch 95/100
# 800/800 [==============================] - 0s 40us/step - loss: 32274836.5000 - mean_absolute_error: 4225.8530 - val_loss: 266421184.0000 - val_mean_absolute_error: 16189.7891
# Epoch 96/100
# 800/800 [==============================] - 0s 40us/step - loss: 32274802.0000 - mean_absolute_error: 4225.8490 - val_loss: 266421024.0000 - val_mean_absolute_error: 16189.7842
# Epoch 97/100
# 800/800 [==============================] - 0s 40us/step - loss: 32274768.0000 - mean_absolute_error: 4225.8448 - val_loss: 266420880.0000 - val_mean_absolute_error: 16189.7803
# Epoch 98/100
# 800/800 [==============================] - 0s 51us/step - loss: 32274735.0000 - mean_absolute_error: 4225.8411 - val_loss: 266420800.0000 - val_mean_absolute_error: 16189.7764
# Epoch 99/100
# 800/800 [==============================] - 0s 38us/step - loss: 32274701.0000 - mean_absolute_error: 4225.8370 - val_loss: 266420656.0000 - val_mean_absolute_error: 16189.7725
# Epoch 100/100
# 800/800 [==============================] - 0s 37us/step - loss: 32274669.0000 - mean_absolute_error: 4225.8334 - val_loss: 266420528.0000 - val_mean_absolute_error: 16189.7686
# Train on 800 samples, validate on 200 samples
# Epoch 1/100
# 800/800 [==============================] - 9s 11ms/step - loss: 32253040.5000 - mean_absolute_error: 4224.1994 - val_loss: 266089536.0000 - val_mean_absolute_error: 16179.6299
# Epoch 2/100
# 800/800 [==============================] - 0s 45us/step - loss: 32215335.0000 - mean_absolute_error: 4221.2790 - val_loss: 266039168.0000 - val_mean_absolute_error: 16178.0859
# Epoch 3/100
# 800/800 [==============================] - 0s 39us/step - loss: 32206398.5000 - mean_absolute_error: 4220.5750 - val_loss: 265984896.0000 - val_mean_absolute_error: 16176.4209
# Epoch 4/100
# 800/800 [==============================] - 0s 39us/step - loss: 32196660.5000 - mean_absolute_error: 4219.8011 - val_loss: 265925280.0000 - val_mean_absolute_error: 16174.5947
# Epoch 5/100
# 800/800 [==============================] - 0s 37us/step - loss: 32185887.5000 - mean_absolute_error: 4218.9507 - val_loss: 265858992.0000 - val_mean_absolute_error: 16172.5596
# Epoch 6/100
# 800/800 [==============================] - 0s 38us/step - loss: 32173951.0000 - mean_absolute_error: 4218.0096 - val_loss: 265785712.0000 - val_mean_absolute_error: 16170.3135
# Epoch 7/100
# 800/800 [==============================] - 0s 51us/step - loss: 32160793.5000 - mean_absolute_error: 4216.9733 - val_loss: 265705344.0000 - val_mean_absolute_error: 16167.8496
# Epoch 8/100
# 800/800 [==============================] - 0s 37us/step - loss: 32146439.5000 - mean_absolute_error: 4215.8388 - val_loss: 265617920.0000 - val_mean_absolute_error: 16165.1660
# Epoch 9/100
# Epoch 43/100
# 800/800 [==============================] - 0s 42us/step - loss: 30066947.5000 - mean_absolute_error: 4048.4121 - val_loss: 253173104.0000 - val_mean_absolute_error: 15778.7627
# Epoch 44/100
# 800/800 [==============================] - 0s 40us/step - loss: 29950317.0000 - mean_absolute_error: 4038.6954 - val_loss: 252477360.0000 - val_mean_absolute_error: 15756.8809
# Epoch 45/100
# 800/800 [==============================] - 0s 43us/step - loss: 29829851.5000 - mean_absolute_error: 4028.7672 - val_loss: 251755952.0000 - val_mean_absolute_error: 15734.1611
# Epoch 46/100
# 800/800 [==============================] - 0s 40us/step - loss: 29703983.0000 - mean_absolute_error: 4018.6255 - val_loss: 250999200.0000 - val_mean_absolute_error: 15710.2939
# Epoch 47/100
# 800/800 [==============================] - 0s 40us/step - loss: 29573828.0000 - mean_absolute_error: 4007.6738 - val_loss: 250222160.0000 - val_mean_absolute_error: 15685.7471
# Epoch 48/100
# 800/800 [==============================] - 0s 42us/step - loss: 29438554.5000 - mean_absolute_error: 3996.8205 - val_loss: 249405120.0000 - val_mean_absolute_error: 15659.8945
# Epoch 49/100
# 800/800 [==============================] - 0s 39us/step - loss: 29298323.0000 - mean_absolute_error: 3985.0884 - val_loss: 248571904.0000 - val_mean_absolute_error: 15633.4902
# Epoch 50/100
# 800/800 [==============================] - 0s 40us/step - loss: 29154779.0000 - mean_absolute_error: 3973.0770 - val_loss: 247711664.0000 - val_mean_absolute_error: 15606.1826
# Epoch 51/100
# 800/800 [==============================] - 0s 42us/step - loss: 29006076.5000 - mean_absolute_error: 3960.8774 - val_loss: 246815520.0000 - val_mean_absolute_error: 15577.6787
# Epoch 52/100
# 800/800 [==============================] - 0s 42us/step - loss: 28852102.5000 - mean_absolute_error: 3948.0123 - val_loss: 245891728.0000 - val_mean_absolute_error: 15548.2451
# Epoch 53/100
# 800/800 [==============================] - 0s 36us/step - loss: 28693992.5000 - mean_absolute_error: 3934.6054 - val_loss: 244943728.0000 - val_mean_absolute_error: 15517.9834
# Epoch 54/100
# ...
# Epoch 16/100
# 800/800 [==============================] - 0s 56us/step - loss: 31986597.0000 - mean_absolute_error: 4202.8033 - val_loss: 264509664.0000 - val_mean_absolute_error: 16131.1201
# Epoch 17/100
# 800/800 [==============================] - 0s 51us/step - loss: 31910140.0000 - mean_absolute_error: 4196.6824 - val_loss: 264017872.0000 - val_mean_absolute_error: 16115.9922
# Epoch 18/100
# 800/800 [==============================] - 0s 52us/step - loss: 31818755.0000 - mean_absolute_error: 4189.3048 - val_loss: 263431904.0000 - val_mean_absolute_error: 16097.9453
# Epoch 19/100
# 800/800 [==============================] - 0s 55us/step - loss: 31710003.5000 - mean_absolute_error: 4180.6432 - val_loss: 262740096.0000 - val_mean_absolute_error: 16076.6201
# Epoch 20/100
# 800/800 [==============================] - 0s 50us/step - loss: 31583295.0000 - mean_absolute_error: 4170.4202 - val_loss: 261933136.0000 - val_mean_absolute_error: 16051.7051
# Epoch 21/100
# Epoch 38/100
# 800/800 [==============================] - 0s 67us/step - loss: 21035467.0000 - mean_absolute_error: 3255.6257 - val_loss: 193919920.0000 - val_mean_absolute_error: 13791.8984
# Epoch 39/100
# 800/800 [==============================] - 0s 57us/step - loss: 19690776.5000 - mean_absolute_error: 3127.5696 - val_loss: 184955712.0000 - val_mean_absolute_error: 13465.9365
# Epoch 40/100
# 800/800 [==============================] - 0s 56us/step - loss: 18253794.0000 - mean_absolute_error: 2988.4890 - val_loss: 175252768.0000 - val_mean_absolute_error: 13104.0254
# Epoch 41/100
# 800/800 [==============================] - 0s 59us/step - loss: 16747225.0000 - mean_absolute_error: 2837.1222 - val_loss: 164971424.0000 - val_mean_absolute_error: 12709.3574
# Epoch 42/100
# 800/800 [==============================] - 0s 59us/step - loss: 15170588.5000 - mean_absolute_error: 2679.5682 - val_loss: 153945952.0000 - val_mean_absolute_error: 12272.1064
# Epoch 43/100
# 800/800 [==============================] - 0s 59us/step - loss: 13545353.0000 - mean_absolute_error: 2509.5415 - val_loss: 142367664.0000 - val_mean_absolute_error: 11795.5928
# Epoch 44/100
# 800/800 [==============================] - 0s 61us/step - loss: 11887564.0000 - mean_absolute_error: 2338.2776 - val_loss: 130261872.0000 - val_mean_absolute_error: 11275.9922
# Epoch 45/100
# 800/800 [==============================] - 0s 58us/step - loss: 10234321.0000 - mean_absolute_error: 2155.1161 - val_loss: 117649544.0000 - val_mean_absolute_error: 10708.0088
# Epoch 46/100
# 800/800 [==============================] - 0s 61us/step - loss: 8634964.5000 - mean_absolute_error: 1978.0785 - val_loss: 105151992.0000 - val_mean_absolute_error: 10113.9971
# Epoch 47/100
# 800/800 [==============================] - 0s 68us/step - loss: 7139218.6250 - mean_absolute_error: 1808.5160 - val_loss: 92666800.0000 - val_mean_absolute_error: 9483.7490
# Epoch 48/100
# 800/800 [==============================] - 0s 59us/step - loss: 5775701.3750 - mean_absolute_error: 1653.7526 - val_loss: 80580960.0000 - val_mean_absolute_error: 8831.2412
# Epoch 49/100
# 800/800 [==============================] - 0s 60us/step - loss: 4611536.3125 - mean_absolute_error: 1524.5610 - val_loss: 69363720.0000 - val_mean_absolute_error: 8179.5557
# Epoch 50/100
# 800/800 [==============================] - 0s 55us/step - loss: 3678408.8125 - mean_absolute_error: 1419.7809 - val_loss: 59220988.0000 - val_mean_absolute_error: 7542.3955
# Epoch 51/100
# 800/800 [==============================] - 0s 58us/step - loss: 2987128.0625 - mean_absolute_error: 1344.5664 - val_loss: 50358524.0000 - val_mean_absolute_error: 6938.3789
# Epoch 52/100
# 800/800 [==============================] - 0s 62us/step - loss: 2543458.1875 - mean_absolute_error: 1306.6150 - val_loss: 43509048.0000 - val_mean_absolute_error: 6433.2236
# Epoch 53/100
# 800/800 [==============================] - 0s 57us/step - loss: 2311973.2188 - mean_absolute_error: 1299.6111 - val_loss: 38845020.0000 - val_mean_absolute_error: 6065.4917
# Epoch 54/100
# 800/800 [==============================] - 0s 56us/step - loss: 2207120.7500 - mean_absolute_error: 1293.2585 - val_loss: 35695024.0000 - val_mean_absolute_error: 5804.1299
# Epoch 55/100
# 800/800 [==============================] - 0s 59us/step - loss: 2169514.4375 - mean_absolute_error: 1296.3182 - val_loss: 33462456.0000 - val_mean_absolute_error: 5611.6465
# Epoch 56/100
# 800/800 [==============================] - 0s 58us/step - loss: 2159952.8750 - mean_absolute_error: 1303.5983 - val_loss: 32735976.0000 - val_mean_absolute_error: 5547.6094
# Epoch 57/100
# 800/800 [==============================] - 0s 56us/step - loss: 2158869.5938 - mean_absolute_error: 1307.7525 - val_loss: 33270568.0000 - val_mean_absolute_error: 5594.8687
# Epoch 58/100
# 800/800 [==============================] - 0s 57us/step - loss: 2154719.3750 - mean_absolute_error: 1305.1623 - val_loss: 33690416.0000 - val_mean_absolute_error: 5631.7168
# Epoch 59/100
# 800/800 [==============================] - 0s 67us/step - loss: 2158462.5938 - mean_absolute_error: 1305.3100 - val_loss: 34172252.0000 - val_mean_absolute_error: 5673.7061
# Epoch 60/100
# 800/800 [==============================] - 0s 61us/step - loss: 2147998.0312 - mean_absolute_error: 1297.5906 - val_loss: 31556948.0000 - val_mean_absolute_error: 5442.1782
# Epoch 61/100
# 800/800 [==============================] - 0s 60us/step - loss: 2156970.5000 - mean_absolute_error: 1302.3000 - val_loss: 30298360.0000 - val_mean_absolute_error: 5327.2358
# Epoch 62/100
# 800/800 [==============================] - 0s 59us/step - loss: 2143067.4375 - mean_absolute_error: 1305.2860 - val_loss: 35596532.0000 - val_mean_absolute_error: 5796.0649
# Epoch 63/100
# 800/800 [==============================] - 0s 53us/step - loss: 2146352.4375 - mean_absolute_error: 1296.1292 - val_loss: 33024784.0000 - val_mean_absolute_error: 5573.4131
# Epoch 64/100
# 800/800 [==============================] - 0s 58us/step - loss: 2139649.4688 - mean_absolute_error: 1296.9836 - val_loss: 31615302.0000 - val_mean_absolute_error: 5447.5894
# Epoch 65/100
# 800/800 [==============================] - 0s 56us/step - loss: 2138739.4688 - mean_absolute_error: 1304.6994 - val_loss: 35938364.0000 - val_mean_absolute_error: 5825.1250
# Epoch 66/100
# 800/800 [==============================] - 0s 58us/step - loss: 2149976.1875 - mean_absolute_error: 1296.8399 - val_loss: 34667616.0000 - val_mean_absolute_error: 5716.7495
# Epoch 67/100
# 800/800 [==============================] - 0s 51us/step - loss: 2138363.5938 - mean_absolute_error: 1293.0224 - val_loss: 31652844.0000 - val_mean_absolute_error: 5451.0806
# Epoch 68/100
# 800/800 [==============================] - 0s 53us/step - loss: 2130179.5000 - mean_absolute_error: 1297.6263 - val_loss: 33204678.0000 - val_mean_absolute_error: 5589.4419
# Epoch 69/100
# 800/800 [==============================] - 0s 52us/step - loss: 2137601.5625 - mean_absolute_error: 1289.5758 - val_loss: 28337972.0000 - val_mean_absolute_error: 5143.3867
# Epoch 70/100
# 800/800 [==============================] - 0s 51us/step - loss: 2134911.7812 - mean_absolute_error: 1301.5480 - val_loss: 33737052.0000 - val_mean_absolute_error: 5636.1875
# Epoch 71/100
# 800/800 [==============================] - 0s 53us/step - loss: 2169986.1875 - mean_absolute_error: 1305.1548 - val_loss: 34067088.0000 - val_mean_absolute_error: 5664.9688
# Epoch 72/100
# 800/800 [==============================] - 0s 52us/step - loss: 2129191.5625 - mean_absolute_error: 1297.8029 - val_loss: 34527888.0000 - val_mean_absolute_error: 5704.8979
# Epoch 73/100
# 800/800 [==============================] - 0s 52us/step - loss: 2117919.0000 - mean_absolute_error: 1283.2530 - val_loss: 31530252.0000 - val_mean_absolute_error: 5440.2075
# Epoch 74/100
# 800/800 [==============================] - 0s 52us/step - loss: 2123970.9688 - mean_absolute_error: 1299.5089 - val_loss: 34819956.0000 - val_mean_absolute_error: 5730.1021
# Epoch 75/100
# 800/800 [==============================] - 0s 54us/step - loss: 2124828.4375 - mean_absolute_error: 1292.4103 - val_loss: 35750032.0000 - val_mean_absolute_error: 5809.4976
# Epoch 76/100
# 800/800 [==============================] - 0s 55us/step - loss: 2127703.3438 - mean_absolute_error: 1285.3801 - val_loss: 31034672.0000 - val_mean_absolute_error: 5395.3076
# Epoch 77/100
# 800/800 [==============================] - 0s 53us/step - loss: 2123345.5938 - mean_absolute_error: 1286.8229 - val_loss: 28167838.0000 - val_mean_absolute_error: 5127.3818
# Epoch 78/100
# 800/800 [==============================] - 0s 54us/step - loss: 2134326.6875 - mean_absolute_error: 1302.0045 - val_loss: 32690842.0000 - val_mean_absolute_error: 5544.3438
# Epoch 79/100
# 800/800 [==============================] - 0s 53us/step - loss: 2103258.9375 - mean_absolute_error: 1285.6284 - val_loss: 32100122.0000 - val_mean_absolute_error: 5491.6982
# Epoch 80/100
# 800/800 [==============================] - 0s 49us/step - loss: 2102752.9062 - mean_absolute_error: 1284.3210 - val_loss: 30548614.0000 - val_mean_absolute_error: 5350.9448
# Epoch 81/100
# 800/800 [==============================] - 0s 55us/step - loss: 2110670.7500 - mean_absolute_error: 1287.4834 - val_loss: 30556250.0000 - val_mean_absolute_error: 5351.6812
# Epoch 82/100
# 800/800 [==============================] - 0s 60us/step - loss: 2119732.5625 - mean_absolute_error: 1288.8113 - val_loss: 31288300.0000 - val_mean_absolute_error: 5418.5845
# Epoch 83/100
# 800/800 [==============================] - 0s 51us/step - loss: 2104099.6250 - mean_absolute_error: 1291.8620 - val_loss: 34780512.0000 - val_mean_absolute_error: 5727.0000
# Epoch 84/100
# 800/800 [==============================] - 0s 52us/step - loss: 2106929.2812 - mean_absolute_error: 1272.4079 - val_loss: 28017966.0000 - val_mean_absolute_error: 5113.2427
# Epoch 85/100
# 800/800 [==============================] - 0s 51us/step - loss: 2116092.0312 - mean_absolute_error: 1292.8106 - val_loss: 31119416.0000 - val_mean_absolute_error: 5403.3311
# Epoch 86/100
# 800/800 [==============================] - 0s 51us/step - loss: 2092937.5000 - mean_absolute_error: 1286.6029 - val_loss: 34299352.0000 - val_mean_absolute_error: 5685.5879
# Epoch 87/100
# 800/800 [==============================] - 0s 52us/step - loss: 2111428.7188 - mean_absolute_error: 1272.8704 - val_loss: 30608704.0000 - val_mean_absolute_error: 5356.7012
# Epoch 88/100
# 800/800 [==============================] - 0s 53us/step - loss: 2092206.5625 - mean_absolute_error: 1281.6890 - val_loss: 30710062.0000 - val_mean_absolute_error: 5366.0356
# Epoch 89/100
# 800/800 [==============================] - 0s 52us/step - loss: 2109262.8750 - mean_absolute_error: 1284.9460 - val_loss: 32118648.0000 - val_mean_absolute_error: 5493.6895
# Epoch 90/100
# 800/800 [==============================] - 0s 53us/step - loss: 2079493.9688 - mean_absolute_error: 1281.5284 - val_loss: 34472672.0000 - val_mean_absolute_error: 5700.6992
# Epoch 91/100
# 800/800 [==============================] - 0s 51us/step - loss: 2078854.2500 - mean_absolute_error: 1273.4141 - val_loss: 32324596.0000 - val_mean_absolute_error: 5512.1699
# Epoch 92/100
# 800/800 [==============================] - 0s 51us/step - loss: 2096132.9062 - mean_absolute_error: 1277.1261 - val_loss: 30412272.0000 - val_mean_absolute_error: 5338.8057
# Epoch 93/100
# 800/800 [==============================] - 0s 54us/step - loss: 2088419.6875 - mean_absolute_error: 1282.1542 - val_loss: 32543078.0000 - val_mean_absolute_error: 5531.7046
# Epoch 94/100
# 800/800 [==============================] - 0s 54us/step - loss: 2071635.0312 - mean_absolute_error: 1274.9682 - val_loss: 32071388.0000 - val_mean_absolute_error: 5489.6211
# Epoch 95/100
# 800/800 [==============================] - 0s 51us/step - loss: 2066931.4062 - mean_absolute_error: 1277.2576 - val_loss: 34961816.0000 - val_mean_absolute_error: 5742.9395
# Epoch 96/100
# 800/800 [==============================] - 0s 58us/step - loss: 2074111.2812 - mean_absolute_error: 1268.5923 - val_loss: 32300916.0000 - val_mean_absolute_error: 5510.2236
# Epoch 97/100
# 800/800 [==============================] - 0s 53us/step - loss: 2087874.3438 - mean_absolute_error: 1275.5767 - val_loss: 33123450.0000 - val_mean_absolute_error: 5583.2305
# Epoch 98/100
# 800/800 [==============================] - 0s 54us/step - loss: 2075341.8125 - mean_absolute_error: 1271.4723 - val_loss: 30472752.0000 - val_mean_absolute_error: 5344.5864
# Epoch 99/100
# 800/800 [==============================] - 0s 56us/step - loss: 2075078.9062 - mean_absolute_error: 1278.0656 - val_loss: 33396700.0000 - val_mean_absolute_error: 5607.3306
# Epoch 100/100
# 800/800 [==============================] - 0s 57us/step - loss: 2065904.0312 - mean_absolute_error: 1269.0865 - val_loss: 31790790.0000 - val_mean_absolute_error: 5464.6221

# %%
plt.semilogy(err_t_list)
plt.semilogy(err_v_v)

# %%
err_t_list
# Out:
# [6708.969948867443,
#  2496.998547371762,
#  2898.7026785186104,
#  3728.773040755871,
#  5034.058354111237,
#  2020.4841705727245,
#  3497.680239933822,
#  1635.3922353838789,
#  2109.6539710997604,
#  1446.9769678623882,
#  1440.5820290200413,
#  3372.1211813434957,
#  4240.484377339482,
#  2512.039859669609,
#  1838.9140016415738,
#  1859.2791039676406,
#  4108.823660203023,
#  1937.3301232876256,
#  2397.605450419616,
#  2203.263907289505]

# %% [markdown]
# ### And now even a more complex one
#
# Let's try to predict now this function:
#
# $\displaystyle y = \cos(x)$
